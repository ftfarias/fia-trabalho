# %% [markdown]
# ação.
# API: https://www.sptrans.com.br/desenvolvedores
# ENDPOINTS:https://www.sptrans.com.br/desenvolvedores/api-do-olho-vivo-guia-de-r
# eferencia/documentacao-api/
# Utilizar o GTFS da SPTRANS para dados complementares (Dados
# Estáticos/Cadastrais).
# Enriquecer os dados de paradas com o endereço da localidade, através de latitude e
# longitude.
# Dados do GTFS: https://gtfs.org/documentation/schedule/reference/

# %%
import requests
import pandas as pd
API_TOKEN = "36b9de7cf0f0bcd8cdde826217615c1b5d2e7b71c80397ec50d1ec7620b4f872"
BASE_URL = "http://api.olhovivo.sptrans.com.br/v2.1"
BASE_PATH = ''

# %%
session = requests.Session()
def authenticate(api_token):
     # Define the authentication endpoint
    auth_endpoint = f"{BASE_URL}/Login/Autenticar?token={api_token}"
    
    try:
        # Make a POST request to authenticate
        response = session.post(auth_endpoint)
        
        # Check if the authentication was successful
        if response.status_code == 200:
            return response
        else:
            print(f"Erro, status: {response.status_code}")
            return False
    except requests.exceptions.RequestException as e:
        print(f"Erro: {e}")
        return False


result = authenticate(API_TOKEN)
print(result.text)
# Out:
# true

# %%
def buscar_linha_sentido(session, termosBusca):
     # Define the authentication endpoint
    endpoint = f"{BASE_URL}/Linha/Buscar?termosBusca={termosBusca}"
    
    try:
        # Make a POST request to authenticate
        response = session.get(endpoint)
        
        # Check if the authentication was successful
        if response.status_code == 200:
            return response
        else:
            print(f"Erro, status: {response.status_code}")
            return response
    except requests.exceptions.RequestException as e:
        print(f"Erro: {e}")
        return False


result = buscar_linha_sentido(session, '8000')
print(result.text)
# Out:
# [{"cl":2506,"lc":false,"lt":"8000","sl":1,"tl":1,"tp":"PÇA. RAMOS DE AZEVEDO","ts":"TERM. LAPA"},{"cl":35274,"lc":false,"lt":"8000","sl":2,"tl":1,"tp":"PÇA. RAMOS DE AZEVEDO","ts":"TERM. LAPA"},{"cl":1273,"lc":false,"lt":"8000","sl":1,"tl":10,"tp":"PÇA. RAMOS DE AZEVEDO","ts":"TERM. LAPA"},{"cl":34041,"lc":false,"lt":"8000","sl":2,"tl":10,"tp":"PÇA. RAMOS DE AZEVEDO","ts":"TERM. LAPA"}]

# %%
import json

def generic_get(session, endpoint):
     # Define the authentication endpoint
    endpoint = BASE_URL + endpoint    
    print(endpoint)
    try:
        # Make a POST request to authenticate
        response = session.get(endpoint)
        
        # Check if the authentication was successful
        if response.status_code == 200:
            return response
        else:
            print(f"Erro, status: {response.status_code}")
            return response
    except requests.exceptions.RequestException as e:
        print(f"Erro: {e}")
        return False

def kmz(session):
    return generic_get(session, '/KMZ')

def parada_buscar(session, termos_busca):
    return generic_get(session, f"/Parada/Buscar?termosBusca='{termos_busca}'")

def parada_buscar_por_linha(session, codigo_linha):
    return generic_get(session, f"/Parada/BuscarParadasPorLinha?codigoLinha={codigo_linha}")

def previsao_parada(session, codigo_parada):
    return generic_get(session, f'/Previsao/Parada?codigoParada={codigo_parada}')

def posicao(session):
    return generic_get(session, f'/Posicao')

def posicao_por_linha(session, codigo_linha):
    return generic_get(session, f"/Posicao/Linha?codigoLinha={codigo_linha}")

# paradas = parada_buscar(session, 'rebouças');
# print(json.dumps(result.json(), indent=4))

# result = parada_buscar_por_linha(session, '1171')
# print(json.dumps(result.json(), indent=4))

# result = previsao_parada(session, '630015011')
# print(json.dumps(result.json(), indent=4))

result = posicao(session)
print(json.dumps(result.json(), indent=2))

# result = posicao_por_linha(session, 1171)
# print(json.dumps(result.json(), indent=2))
# Out:
# http://api.olhovivo.sptrans.com.br/v2.1/Posicao
# {
#   "hr": "20:05",
#   "l": [
#     {
#       "c": "6913-10",
#       "cl": 34233,
#       "sl": 2,
#       "lt0": "TERM. BANDEIRA",
#       "lt1": "TERM. VARGINHA",
#       "qv": 16,
#       "vs": [
#         {
#           "p": 61351,
#           "a": true,
#           "ta": "2025-01-22T23:05:03Z",
#           "py": -23.63722225,
#           "px": -46.69631025,
#           "sv": null,
#           "is": null
#         },
#         {
#           "p": 61582,
#           "a": true,
#           "ta": "2025-01-22T23:05:00Z",
#           "py": -23.7264145,
#           "px": -46.699558249999995,
#           "sv": null,
#           "is": null
#         },
#         {
#           "p": 61348,
#           "a": true,
#           "ta": "2025-01-22T23:04:51Z",
#           "py": -23.7253535,
#           "px": -46.699728500000006,
#           "sv": null,
#           "is": null
#         },
#         {
#           "p": 61324,
#           "a": true,
#           "ta": "2025-01-22T23:05:03Z",
#           "py": -23.636039,
#           "px": -46.6954255,
#           "sv": null,
#           "is": null
#         },
#         {
#           "p": 61071,
#           "a": true,
#           "ta": "2025-01-22T23:04:32Z",
#           "py": -23.766492,
#           "px": -46.716403,
#           "sv": null,
#           "is": null
#         },
#         {
#           "p": 61381,
#           "a": true,
#           "ta": "2025-01-22T23:04:58Z",
#           "py": -23.737624,
#           "px": -46.699929499999996,
#           "sv": null,
#           "is": null
#         },
#         {
#           "p": 61665,
#           "a": true,
#           "ta": "2025-01-22T23:04:59Z",
#           "py": -23.662931125,
#           "px": -46.70718,
#           "sv": null,
#           "is": null
#         },
#         {
#           "p": 61352,
#           "a": true,
#           "ta": "2025-01-22T23:05:09Z",
#           "py": -23.662931125,
#           "px": -46.70718,
#           "sv": null,
#           "is": null
#         },
#         {
#           "p": 61772,
#           "a": true,
#           "ta": "2025-01-22T23:05:02Z",
#           "py": -23.6123915,
#           "px": -46.678042,
#           "sv": null,
#           "is": null
#         },
#         {
#           "p": 61344,
#           "a": true,
#           "ta": "2025-01-22T23:04:35Z",
#           "py": -23.549266,
#           "px": -46.6401115,
#           "sv": null,
#           "is": null
#         },
#         {
#           "p": 61743,
#           "a": true,
#           "ta": "2025-01-22T23:04:45Z",
#           "py": -23.644555000000004,
#           "px": -46.701621375,
#           "sv": null,
#           "is": null
#         },
#         {
#           "p": 61350,
#           "a": true,
#           "ta": "2025-01-22T23:05:00Z",
#           "py": -23.5589985,
#           "px": -46.6541765,
#           "sv": null,
#           "is": null
#         },
#         {
#           "p": 61072,
#           "a": true,
#           "ta": "2025-01-22T23:05:02Z",
#           "py": -23.549266,
#           "px": -46.6401115,
#           "sv": null,
#           "is": null
#         },
#         {
#           "p": 61311,
#           "a": true,
#           "ta": "2025-01-22T23:04:36Z",
#           "py": -23.767727999999998,
#           "px": -46.7167135,
#           "sv": null,
#           "is": null
#         },
#         {
#           "p": 61678,
#           "a": true,
#           "ta": "2025-01-22T23:05:02Z",
#           "py": -23.6289175,
#           "px": -46.689211,
#           "sv": null,
#           "is": null
#         },
#         {
#           "p": 61657,
#           "a": true,
#           "ta": "2025-01-22T23:04:45Z",
#           "py": -23.7662805,
#           "px": -46.717397500000004,
#           "sv": null,
#           "is": null
#         }
#       ]
#     },
#     {
#       "c": "5129-10",
#       "cl": 34049,
#       "sl": 2,
#       "lt0": "TERM. GUARAPIRANGA",
#       "lt1": "JD. MIRIAM",
#       "qv": 7,
#       "vs": [
#         {
#           "p": 63178,
#           "a": true,
#           "ta": "2025-01-22T23:04:55Z",
#           "py": -23.6829465,
#           "px": -46.63545125,
#           "sv": null,
#           "is": null
#         },
#         {
#           "p": 63186,
#           "a": true,
#           "ta": "2025-01-22T23:04:43Z",
#           "py": -23.680145875,
#           "px": -46.69566400000001,
#           "sv": null,
#           "is": null
#         },
#         {
#           "p": 63190,
#           "a": true,
#           "ta": "2025-01-22T23:04:36Z",
#           "py": -23.666456500000002,
#           "px": -46.7063305,
#           "sv": null,
#           "is": null
#         },
#         {
#           "p": 63586,
#           "a": true,
#           "ta": "2025-01-22T23:04:33Z",
#           "py": -23.6802855,
#           "px": -46.637386,
#           "sv": null,
#           "is": null
#         },
#         {
#           "p": 63184,
#           "a": true,
#           "ta": "2025-01-22T23:04:48Z",
#           "py": -23.6550135,
#           "px": -46.6797735,
#           "sv": null,
#           "is": null
#         },
#         {
#           "p": 63169,
#           "a": true,
#           "ta": "2025-01-22T23:04:25Z",
#           "py": -23.6835835,
#           "px": -46.634378999999996,
#           "sv": null,
#           "is": null
#         },
#         {
#           "p": 63171,
#           "a": true,
#           "ta": "2025-01-22T23:04:36Z",
#           "py": -23.667242,
#           "px": -46.65416825,
#           "sv": null,
#           "is": null
#         }
#       ]
#     },
#     {
#       "c": "7055-10",
#       "cl": 34656,
#       "sl": 2,
#       "lt0": "TERM. CAMPO LIMPO",
#       "lt1": "JD. GUARUJ\u00c1",
#       "qv": 9,
#       "vs": [
#         {
#           "p": 78793,
#           "a": true,
#           "ta": "2025-01-22T23:05:05Z",
#           "py": -23.6924125,
#           "px": -46.790126,
#           "sv": null,
#           "is": null
#         },
#         {
#           "p": 78235,
#           "a": true,
#           "ta": "2025-01-22T23:05:04Z",
#           "py": -23.690268500000002,
#           "px": -46.78884600000001,
#           "sv": null,
#           "is": null
#         },
#         {
#           "p": 78809,
#           "a": true,
#           "ta": "2025-01-22T23:04:53Z",
#           "py": -23.6926985,
#           "px": -46.7912795,
#           "sv": null,
#           "is": null
#         },
#         {
#           "p": 78364,
#           "a": true,
#           "ta": "2025-01-22T23:04:45Z",
#           "py": -23.6896555,
#           "px": -46.789497,
#           "sv": null,
#           "is": null
#         },
#         {
#           "p": 78474,
#           "a": true,
#           "ta": "2025-01-22T23:04:27Z",
#           "py": -23.649175,
#           "px": -46.7793,
#           "sv": null,
#           "is": null
#         },
#         {
#           "p": 78599,
#           "a": true,
#           "ta": "2025-01-22T23:04:39Z",
#           "py": -23.667396500000002,
#           "px": -46.773017499999995,
#           "sv": null,
#           "is": null
#         },
#         {
#           "p": 78491,
#           "a": true,
#           "ta": "2025-01-22T23:04:46Z",
#           "py": -23.660277999999998,
#           "px": -46.768888000000004,
#           "sv": null,
#           "is": null
#         },
#         {
#           "p": 78841,
#           "a": true,
#           "ta": "2025-01-22T23:04:39Z",
#           "py": -23.690446,
#           "px": -46.788742,
#           "sv": null,
#           "is": null
#         },
#         {
#           "p": 78819,
#           "a": true,
#           "ta": "2025-01-22T23:05:00Z",
#           "py": -23.65994775,
#           "px": -46.7708045,
#           "sv": null,
#           "is": null
#         }
#       ]
#     },
#     {
#       "c": "917H-10",
#       "cl": 456,
#       "sl": 1,
#       "lt0": "METR\u00d4 VL. MARIANA",
#       "lt1": "TERM. PIRITUBA",
#       "qv": 15,
#       "vs": [
#         {
#           "p": 11904,
#           "a": true,
#           "ta": "2025-01-22T23:04:44Z",
#           "py": -23.4865925,
#           "px": -46.726296500000004,
#           "sv": null,
#           "is": null
#         },
#         {
#           "p": 11885,
#           "a": true,
#           "ta": "2025-01-22T23:04:56Z",
#           "py": -23.555668999999998,
#           "px": -46.66729625,
#           "sv": null,
#           "is": null
#         },
#         {
#           "p": 11895,
#           "a": true,
#           "ta": "2025-01-22T23:04:53Z",
#           "py": -23.486438,
#           "px": -46.726151,
#           "sv": null,
#           "is": null
#         },
#         {
#           "p": 11903,
#           "a": true,
#           "ta": "2025-01-22T23:04:50Z",
#           "py": -23.486517,
#           "px": -46.7262255,
#           "sv": null,
#           "is": null
#         },
#         {
#           "p": 11905,
#           "a": true,
#           "ta": "2025-01-22T23:04:27Z",
#           "py": -23.5190255,
#           "px": -46.753200500000005,
#           "sv": null,
#           "is": null
#         },
#         {
#           "p": 11887,
#           "a": true,
#           "ta": "2025-01-22T23:04:47Z",
#           "py": -23.5407095,
#           "px": -46.7150975,
#           "sv": null,
#           "is": null
#         },
#         {
#           "p": 11892,
#           "a": true,
#           "ta": "2025-01-22T23:05:04Z",
#           "py": -23.487215,
#           "px": -46.726875,
#           "sv": null,
#           "is": null
#         },
#         {
#           "p": 11897,
#           "a": true,
#           "ta": "2025-01-22T23:04:33Z",
#           "py": -23.486517,
#           "px": -46.7262255,
#           "sv": null,
#           "is": null
#         },
#         {
#           "p": 11884,
#           "a": true,
#           "ta": "2025-01-22T23:04:31Z",
#           "py": -23.589263,
#           "px": -46.634504,
#           "sv": null,
#           "is": null
#         },
#         {
#           "p": 11900,
#           "a": true,
#           "ta": "2025-01-22T23:05:03Z",
#           "py": -23.486662000000003,
#           "px": -46.726361,
#           "sv": null,
#           "is": null
#         },
#         {
#           "p": 11902,
#           "a": true,
#           "ta": "2025-01-22T23:05:04Z",
#           "py": -23.486221999999998,
#           "px": -46.725944999999996,
#           "sv": null,
#           "is": null
#         },
#         {
#           "p": 11890,
#           "a": true,
#           "ta": "2025-01-22T23:04:38Z",
#           "py": -23.495824,
#           "px": -46.746669499999996,
#           "sv": null,
#           "is": null
#         },
#         {
#           "p": 11881,
#           "a": true,
#           "ta": "2025-01-22T23:04:28Z",
#           "py": -23.589295999999997,
#           "px": -46.63421325,
#           "sv": null,
#           "is": null
#         },
#         {
#           "p": 11910,
#           "a": true,
#           "ta": "2025-01-22T23:04:32Z",
#           "py": -23.485838,
#           "px": -46.725277500000004,
#           "sv": null,
#           "is": null
#         },
#         {
#           "p": 11882,
#           "a": true,
#           "ta": "2025-01-22T23:05:00Z",
#           "py": -23.584359499999998,
#           "px": -46.636663999999996,
#           "sv": null,
#           "is": null
#         }
#       ]
#     },
#     {
#       "c": "524L-10",
#       "cl": 34483,
#       "sl": 2,
#       "lt0": "METR\u00d4 TATUAP\u00c9",
#       "lt1": "PQ. S\u00c3O LUCAS",
#       "qv": 5,
#       "vs": [
#         {
#           "p": 55441,
#           "a": true,
#           "ta": "2025-01-22T23:04:31Z",
#           "py": -23.542985,
#           "px": -46.5749235,
#           "sv": null,
#           "is": null
#         },
#         {
#           "p": 55433,
#           "a": true,
#           "ta": "2025-01-22T23:04:45Z",
#           "py": -23.598761,
#           "px": -46.5339095,
#           "sv": null,
#           "is": null
#         },
#         {
#           "p": 55065,
#           "a": true,
#           "ta": "2025-01-22T23:04:28Z",
#           "py": -23.598863,
#           "px": -46.533697,
#           "sv": null,
#           "is": null
#         },
#         {
#           "p": 55551,
#           "a": true,
#           "ta": "2025-01-22T23:04:57Z",
#           "py": -23.56778075,
#           "px": -46.559535000000004,
#           "sv": null,
#           "is": null
#         },
#         {
#           "p": 55436,
#           "a": true,
#           "ta": "2025-01-22T23:04:41Z",
#           "py": -23.592827999999997,
#           "px": -46.54524,
#           "sv": null,
#           "is": null
#         }
#       ]
#     },
#     {
#       "c": "177H-10",
#       "cl": 33398,
#       "sl": 2,
#       "lt0": "CID. UNIVERSIT\u00c1RIA",
#       "lt1": "METR\u00d4 SANTANA",
#       "qv": 7,
#       "vs": [
#         {
#           "p": 21938,
#           "a": true,
#           "ta": "2025-01-22T23:04:59Z",
#           "py": -23.503036,
#           "px": -46.624043,
#           "sv": null,
#           "is": null
#         },
#         {
#           "p": 21968,
#           "a": true,
#           "ta": "2025-01-22T23:05:01Z",
#           "py": -23.564087,
#           "px": -46.7151915,
#           "sv": null,
#           "is": null
#         },
#         {
#           "p": 21330,
#           "a": true,
#           "ta": "2025-01-22T23:04:26Z",
#           "py": -23.552421,
#           "px": -46.7320975,
#           "sv": null,
#           "is": null
#         },
#         {
#           "p": 21964,
#           "a": true,
#           "ta": "2025-01-22T23:04:35Z",
#           "py": -23.53642375,
#           "px": -46.652418499999996,
#           "sv": null,
#           "is": null
#         },
#         {
#           "p": 21963,
#           "a": true,
#           "ta": "2025-01-22T23:04:45Z",
#           "py": -23.5028845,
#           "px": -46.6240365,
#           "sv": null,
#           "is": null
#         },
#         {
#           "p": 21240,
#           "a": true,
#           "ta": "2025-01-22T23:04:46Z",
#           "py": -23.504081,
#           "px": -46.65629475,
#           "sv": null,
#           "is": null
#         },
#         {
#           "p": 21969,
#           "a": true,
#           "ta": "2025-01-22T23:05:06Z",
#           "py": -23.56758325,
#           "px": -46.6950595,
#           "sv": null,
#           "is": null
#         }
#       ]
#     },
#     {
#       "c": "2104-10",
#       "cl": 2255,
#       "sl": 1,
#       "lt0": "TERM. PQ. D. PEDRO II",
#       "lt1": "METR\u00d4 SANTANA",
#       "qv": 3,
#       "vs": [
#         {
#           "p": 21301,
#           "a": true,
#           "ta": "2025-01-22T23:04:51Z",
#           "py": -23.546565,
#           "px": -46.630926,
#           "sv": null,
#           "is": null
#         },
#         {
#           "p": 21004,
#           "a": true,
#           "ta": "2025-01-22T23:04:31Z",
#           "py": -23.502102999999998,
#           "px": -46.624000499999994,
#           "sv": null,
#           "is": null
#         },
#         {
#           "p": 21001,
#           "a": true,
#           "ta": "2025-01-22T23:04:25Z",
#           "py": -23.523996500000003,
#           "px": -46.6255045,
#           "sv": null,
#           "is": null
#         }
#       ]
#     },
#     {
#       "c": "7002-10",
#       "cl": 33540,
#       "sl": 2,
#       "lt0": "HOSP. DAS CL\u00cdNICAS",
#       "lt1": "JD. ROSA MARIA",
#       "qv": 10,
#       "vs": [
#         {
#           "p": 86322,
#           "a": true,
#           "ta": "2025-01-22T23:04:56Z",
#           "py": -23.585644000000002,
#           "px": -46.7607455,
#           "sv": null,
#           "is": null
#         },
#         {
#           "p": 86341,
#           "a": true,
#           "ta": "2025-01-22T23:04:32Z",
#           "py": -23.590836,
#           "px": -46.76973625,
#           "sv": null,
#           "is": null
#         },
#         {
#           "p": 86156,
#           "a": true,
#           "ta": "2025-01-22T23:04:26Z",
#           "py": -23.594811,
#           "px": -46.7683595,
#           "sv": null,
#           "is": null
#         },
#         {
#           "p": 86474,
#           "a": true,
#           "ta": "2025-01-22T23:04:23Z",
#           "py": -23.585048,
#           "px": -46.746162999999996,
#           "sv": null,
#           "is": null
#         },
#         {
#           "p": 86162,
#           "a": true,
#           "ta": "2025-01-22T23:04:50Z",
#           "py": -23.590836,
#           "px": -46.76973625,
#           "sv": null,
#           "is": null
#         },
#         {
#           "p": 86049,
#           "a": true,
#           "ta": "2025-01-22T23:05:03Z",
#           "py": -23.590518,
#           "px": -46.76971475,
#           "sv": null,
#           "is": null
#         },
#         {
#           "p": 86021,
#           "a": true,
#           "ta": "2025-01-22T23:04:42Z",
#           "py": -23.567136249999997,
#           "px": -46.69929375,
#           "sv": null,
#           "is": null
#         },
#         {
#           "p": 86343,
#           "a": true,
#           "ta": "2025-01-22T23:05:01Z",
#           "py": -23.58527325,
#           "px": -46.7466845,
#           "sv": null,
#           "is": null
#         },
#         {
#           "p": 86506,
#           "a": true,
#           "ta": "2025-01-22T23:04:43Z",
#           "py": -23.590518,
#           "px": -46.76971475,
#           "sv": null,
#           "is": null
#         },
#         {
#           "p": 86321,
#           "a": true,
#           "ta": "2025-01-22T23:04:38Z",
#           "py": -23.55293175,
#           "px": -46.673462,
#           "sv": null,
#           "is": null
#         }
#       ]
#     },
#     {
#       "c": "2013-10",
#       "cl": 899,
#       "sl": 1,
#       "lt0": "CACHOEIRINHA",
#       "lt1": "COHAB ANT\u00c1RTICA",
#       "qv": 7,
#       "vs": [
#         {
#           "p": 25209,
#           "a": true,
#           "ta": "2025-01-22T23:04:47Z",
#           "py": -23.4546975,
#           "px": -46.658477500000004,
#           "sv": null,
#           "is": null
#         },
#         {
#           "p": 25611,
#           "a": true,
#           "ta": "2025-01-22T23:04:36Z",
#           "py": -23.459288,
#           "px": -46.6566375,
#           "sv": null,
#           "is": null
#         },
#         {
#           "p": 25612,
#           "a": true,
#           "ta": "2025-01-22T23:05:01Z",
#           "py": -23.462000500000002,
#           "px": -46.67289125,
#           "sv": null,
#           "is": null
#         },
#         {
#           "p": 25622,
#           "a": true,
#           "ta": "2025-01-22T23:05:07Z",
#           "py": -23.4682555,
#           "px": -46.660904,
#           "sv": null,
#           "is": null
#         },
#         {
#           "p": 25009,
#           "a": true,
#           "ta": "2025-01-22T23:04:45Z",
#           "py": -23.4546975,
#           "px": -46.658477500000004,
#           "sv": null,
#           "is": null
#         },
#         {
#           "p": 25165,
#           "a": true,
#           "ta": "2025-01-22T23:04:41Z",
#           "py": -23.45582125,
#           "px": -46.655542,
#           "sv": null,
#           "is": null
#         },
#         {
#           "p": 25632,
#           "a": true,
#           "ta": "2025-01-22T23:04:58Z",
#           "py": -23.463915,
#           "px": -46.668356,
#           "sv": null,
#           "is": null
#         }
#       ]
#     },
#     {
#       "c": "736G-10",
#       "cl": 780,
#       "sl": 1,
#       "lt0": "SHOP. MORUMBI",
#       "lt1": "JD. ING\u00c1",
#       "qv": 5,
#       "vs": [
#         {
#           "p": 86211,
#           "a": true,
#           "ta": "2025-01-22T23:04:30Z",
#           "py": -23.633460499999998,
#           "px": -46.7470225,
#           "sv": null,
#           "is": null
#         },
#         {
#           "p": 86325,
#           "a": true,
#           "ta": "2025-01-22T23:04:53Z",
#           "py": -23.618563,
#           "px": -46.6996525,
#           "sv": null,
#           "is": null
#         },
#         {
#           "p": 86225,
#           "a": true,
#           "ta": "2025-01-22T23:04:23Z",
#           "py": -23.618506,
#           "px": -46.699464,
#           "sv": null,
#           "is": null
#         },
#         {
#           "p": 86139,
#           "a": true,
#           "ta": "2025-01-22T23:04:43Z",
#           "py": -23.642785749999998,
#           "px": -46.73786,
#           "sv": null,
#           "is": null
#         },
#         {
#           "p": 86177,
#           "a": true,
#           "ta": "2025-01-22T23:04:38Z",
#           "py": -23.632856500000003,
#           "px": -46.747603999999995,
#           "sv": null,
#           "is": null
#         }
#       ]
#     },
#     {
#       "c": "9701-10",
#       "cl": 569,
#       "sl": 1,
#       "lt0": "METR\u00d4 BARRA FUNDA",
#       "lt1": "CEM. CACHOEIRINHA",
#       "qv": 1,
#       "vs": [
#         {
#           "p": 22899,
#           "a": true,
#           "ta": "2025-01-22T23:04:50Z",
#           "py": -23.519931999999997,
#           "px": -46.667540375,
#           "sv": null,
#           "is": null
#         }
#       ]
#     },
#     {
#       "c": "414P-10",
#       "cl": 33873,
#       "sl": 2,
#       "lt0": "TERM. NORTE METR\u00d4 CARR\u00c3O",
#       "lt1": "VL. INDUSTRIAL",
#       "qv": 9,
#       "vs": [
#         {
#           "p": 55355,
#           "a": true,
#           "ta": "2025-01-22T23:04:34Z",
#           "py": -23.555926499999998,
#           "px": -46.555136,
#           "sv": null,
#           "is": null
#         },
#         {
#           "p": 55041,
#           "a": true,
#           "ta": "2025-01-22T23:04:49Z",
#           "py": -23.57862425,
#           "px": -46.54116675,
#           "sv": null,
#           "is": null
#         },
#         {
#           "p": 55340,
#           "a": true,
#           "ta": "2025-01-22T23:04:52Z",
#           "py": -23.550624499999998,
#           "px": -46.56779,
#           "sv": null,
#           "is": null
#         },
#         {
#           "p": 55171,
#           "a": true,
#           "ta": "2025-01-22T23:04:32Z",
#           "py": -23.53627125,
#           "px": -46.56535075,
#           "sv": null,
#           "is": null
#         },
#         {
#           "p": 55133,
#           "a": true,
#           "ta": "2025-01-22T23:04:42Z",
#           "py": -23.59929,
#           "px": -46.529866,
#           "sv": null,
#           "is": null
#         },
#         {
#           "p": 55352,
#           "a": true,
#           "ta": "2025-01-22T23:05:08Z",
#           "py": -23.596272,
#           "px": -46.527043,
#           "sv": null,
#           "is": null
#         },
#         {
#           "p": 55143,
#           "a": true,
#           "ta": "2025-01-22T23:04:25Z",
#           "py": -23.534955,
#           "px": -46.5755565,
#           "sv": null,
#           "is": null
#         },
#         {
#           "p": 55306,
#           "a": true,
#           "ta": "2025-01-22T23:04:38Z",
#           "py": -23.6105545,
#           "px": -46.529823500000006,
#           "sv": null,
#           "is": null
#         },
#         {
#           "p": 55150,
#           "a": true,
#           "ta": "2025-01-22T23:04:51Z",
#           "py": -23.60529675,
#           "px": -46.53038575,
#           "sv": null,
#           "is": null
#         }
#       ]
#     },
#     {
#       "c": "2626-10",
#       "cl": 33144,
#       "sl": 2,
#       "lt0": "TERM. PQ. D. PEDRO II",
#       "lt1": "JD. NAZAR\u00c9",
#       "qv": 7,
#       "vs": [
#         {
#           "p": 31711,
#           "a": true,
#           "ta": "2025-01-22T23:05:01Z",
#           "py": -23.536765000000003,
#           "px": -46.589805,
#           "sv": null,
#           "is": null
#         },
#         {
#           "p": 31060,
#           "a": true,
#           "ta": "2025-01-22T23:05:04Z",
#           "py": -23.523301,
#           "px": -46.4105365,
#           "sv": null,
#           "is": null
#         },
#         {
#           "p": 31077,
#           "a": true,
#           "ta": "2025-01-22T23:04:51Z",
#           "py": -23.507065750000002,
#           "px": -46.478286,
#           "sv": null,
#           "is": null
#         },
#         {
#           "p": 31071,
#           "a": true,
#           "ta": "2025-01-22T23:04:27Z",
#           "py": -23.523087,
#           "px": -46.410531500000005,
#           "sv": null,
#           "is": null
#         },
#         {
#           "p": 31075,
#           "a": true,
#           "ta": "2025-01-22T23:04:58Z",
#           "py": -23.507192500000002,
#           "px": -46.41142000000001,
#           "sv": null,
#           "is": null
#         },
#         {
#           "p": 31068,
#           "a": true,
#           "ta": "2025-01-22T23:04:34Z",
#           "py": -23.5222035,
#           "px": -46.538377499999996,
#           "sv": null,
#           "is": null
#         },
#         {
#           "p": 31049,
#           "a": true,
#           "ta": "2025-01-22T23:04:37Z",
#           "py": -23.496701,
#           "px": -46.4532215,
#           "sv": null,
#           "is": null
#         }
#       ]
#     },
#     {
#       "c": "1705-10",
#       "cl": 33617,
#       "sl": 2,
#       "lt0": "METR\u00d4 TUCURUVI",
#       "lt1": "JD. S\u00c3O JO\u00c3O",
#       "qv": 7,
#       "vs": [
#         {
#           "p": 26213,
#           "a": true,
#           "ta": "2025-01-22T23:04:54Z",
#           "py": -23.4644525,
#           "px": -46.596099,
#           "sv": null,
#           "is": null
#         },
#         {
#           "p": 26028,
#           "a": true,
#           "ta": "2025-01-22T23:04:30Z",
#           "py": -23.462445125000002,
#           "px": -46.594866999999994,
#           "sv": null,
#           "is": null
#         },
#         {
#           "p": 26508,
#           "a": true,
#           "ta": "2025-01-22T23:04:49Z",
#           "py": -23.44269475,
#           "px": -46.58767725,
#           "sv": null,
#           "is": null
#         },
#         {
#           "p": 26141,
#           "a": true,
#           "ta": "2025-01-22T23:04:33Z",
#           "py": -23.44264425,
#           "px": -46.58803375,
#           "sv": null,
#           "is": null
#         },
#         {
#           "p": 26130,
#           "a": true,
#           "ta": "2025-01-22T23:04:54Z",
#           "py": -23.479108749999998,
#           "px": -46.6055815,
#           "sv": null,
#           "is": null
#         },
#         {
#           "p": 26514,
#           "a": true,
#           "ta": "2025-01-22T23:04:49Z",
#           "py": -23.434097,
#           "px": -46.583839749999996,
#           "sv": null,
#           "is": null
#         },
#         {
#           "p": 26012,
#           "a": true,
#           "ta": "2025-01-22T23:04:44Z",
#           "py": -23.442436,
#           "px": -46.588474,
#           "sv": null,
#           "is": null
#         }
#       ]
#     },
#     {
#       "c": "9789-10",
#       "cl": 33597,
#       "sl": 2,
#       "lt0": "METR\u00d4 BARRA FUNDA",
#       "lt1": "JD. PAULISTANO",
#       "qv": 4,
#       "vs": [
#         {
#           "p": 16466,
#           "a": true,
#           "ta": "2025-01-22T23:04:50Z",
#           "py": -23.46390625,
#           "px": -46.701003,
#           "sv": null,
#           "is": null
#         },
#         {
#           "p": 16722,
#           "a": true,
#           "ta": "2025-01-22T23:05:02Z",
#           "py": -23.483157,
#           "px": -46.69186175,
#           "sv": null,
#           "is": null
#         },
#         {
#           "p": 16249,
#           "a": true,
#           "ta": "2025-01-22T23:04:48Z",
#           "py": -23.48442,
#           "px": -46.690945,
#           "sv": null,
#           "is": null
#         },
#         {
#           "p": 16192,
#           "a": true,
#           "ta": "2025-01-22T23:05:01Z",
#           "py": -23.48644875,
#           "px": -46.688289499999996,
#           "sv": null,
#           "is": null
#         }
#       ]
#     },
#     {
#       "c": "3761-10",
#       "cl": 1051,
#       "sl": 1,
#       "lt0": "METR\u00d4 CARR\u00c3O",
#       "lt1": "3A. DIVIS\u00c3O",
#       "qv": 7,
#       "vs": [
#         {
#           "p": 47216,
#           "a": true,
#           "ta": "2025-01-22T23:05:00Z",
#           "py": -23.618599,
#           "px": -46.4234555,
#           "sv": null,
#           "is": null
#         },
#         {
#           "p": 47690,
#           "a": true,
#           "ta": "2025-01-22T23:04:36Z",
#           "py": -23.5550475,
#           "px": -46.5169645,
#           "sv": null,
#           "is": null
#         },
#         {
#           "p": 47061,
#           "a": true,
#           "ta": "2025-01-22T23:04:26Z",
#           "py": -23.540874000000002,
#           "px": -46.53722,
#           "sv": null,
#           "is": null
#         },
#         {
#           "p": 47576,
#           "a": true,
#           "ta": "2025-01-22T23:04:28Z",
#           "py": -23.5380945,
#           "px": -46.564400750000004,
#           "sv": null,
#           "is": null
#         },
#         {
#           "p": 47378,
#           "a": true,
#           "ta": "2025-01-22T23:04:43Z",
#           "py": -23.615426,
#           "px": -46.422986,
#           "sv": null,
#           "is": null
#         },
#         {
#           "p": 47022,
#           "a": true,
#           "ta": "2025-01-22T23:04:34Z",
#           "py": -23.596271,
#           "px": -46.455373625,
#           "sv": null,
#           "is": null
#         },
#         {
#           "p": 47338,
#           "a": true,
#           "ta": "2025-01-22T23:04:35Z",
#           "py": -23.5964135,
#           "px": -46.456009,
#           "sv": null,
#           "is": null
#         }
#       ]
#     },
#     {
#       "c": "2769-10",
#       "cl": 397,
#       "sl": 1,
#       "lt0": "METR\u00d4 TATUAP\u00c9",
#       "lt1": "JD. ROMANO",
#       "qv": 4,
#       "vs": [
#         {
#           "p": 31062,
#           "a": true,
#           "ta": "2025-01-22T23:04:59Z",
#           "py": -23.507372125000003,
#           "px": -46.488834374999996,
#           "sv": null,
#           "is": null
#         },
#         {
#           "p": 31704,
#           "a": true,
#           "ta": "2025-01-22T23:04:30Z",
#           "py": -23.5231735,
#           "px": -46.533573000000004,
#           "sv": null,
#           "is": null
#         },
#         {
#           "p": 31715,
#           "a": true,
#           "ta": "2025-01-22T23:05:00Z",
#           "py": -23.4818615,
#           "px": -46.379605999999995,
#           "sv": null,
#           "is": null
#         },
#         {
#           "p": 31022,
#           "a": true,
#           "ta": "2025-01-22T23:04:43Z",
#           "py": -23.49118825,
#           "px": -46.4169255,
#           "sv": null,
#           "is": null
#         }
#       ]
#     },
#     {
#       "c": "9188-10",
#       "cl": 33577,
#       "sl": 2,
#       "lt0": "LAPA",
#       "lt1": "CAPELA DA LAGOA ",
#       "qv": 4,
#       "vs": [
#         {
#           "p": 16377,
#           "a": true,
#           "ta": "2025-01-22T23:04:29Z",
#           "py": -23.454522500000003,
#           "px": -46.737875,
#           "sv": null,
#           "is": null
#         },
#         {
#           "p": 16595,
#           "a": true,
#           "ta": "2025-01-22T23:04:29Z",
#           "py": -23.4751275,
#           "px": -46.72450325,
#           "sv": null,
#           "is": null
#         },
#         {
#           "p": 16305,
#           "a": true,
#           "ta": "2025-01-22T23:04:50Z",
#           "py": -23.44985475,
#           "px": -46.733419250000004,
#           "sv": null,
#           "is": null
#         },
#         {
#           "p": 16613,
#           "a": true,
#           "ta": "2025-01-22T23:04:34Z",
#           "py": -23.482787000000002,
#           "px": -46.717287999999996,
#           "sv": null,
#           "is": null
#         }
#       ]
#     },
#     {
#       "c": "6110-10",
#       "cl": 1184,
#       "sl": 1,
#       "lt0": "AEROPORTO",
#       "lt1": "CONJ. HAB. PALMARES",
#       "qv": 4,
#       "vs": [
#         {
#           "p": 64621,
#           "a": true,
#           "ta": "2025-01-22T23:04:51Z",
#           "py": -23.62369875,
#           "px": -46.6615745,
#           "sv": null,
#           "is": null
#         },
#         {
#           "p": 64391,
#           "a": true,
#           "ta": "2025-01-22T23:04:59Z",
#           "py": -23.7451125,
#           "px": -46.707049999999995,
#           "sv": null,
#           "is": null
#         },
#         {
#           "p": 64338,
#           "a": true,
#           "ta": "2025-01-22T23:04:54Z",
#           "py": -23.67908775,
#           "px": -46.68565924999999,
#           "sv": null,
#           "is": null
#         },
#         {
#           "p": 64144,
#           "a": true,
#           "ta": "2025-01-22T23:04:53Z",
#           "py": -23.718954250000003,
#           "px": -46.7039225,
#           "sv": null,
#           "is": null
#         }
#       ]
#     },
#     {
#       "c": "273X-10",
#       "cl": 33160,
#       "sl": 2,
#       "lt0": "METR\u00d4 ARTUR ALVIM",
#       "lt1": "JD. DAS OLIVEIRAS",
#       "qv": 7,
#       "vs": [
#         {
#           "p": 32907,
#           "a": true,
#           "ta": "2025-01-22T23:04:46Z",
#           "py": -23.497997624999996,
#           "px": -46.376735124999996,
#           "sv": null,
#           "is": null
#         },
#         {
#           "p": 32509,
#           "a": true,
#           "ta": "2025-01-22T23:04:34Z",
#           "py": -23.494939,
#           "px": -46.411469,
#           "sv": null,
#           "is": null
#         },
#         {
#           "p": 32169,
#           "a": true,
#           "ta": "2025-01-22T23:04:35Z",
#           "py": -23.498168999999997,
#           "px": -46.376669500000006,
#           "sv": null,
#           "is": null
#         },
#         {
#           "p": 32516,
#           "a": true,
#           "ta": "2025-01-22T23:04:24Z",
#           "py": -23.4968655,
#           "px": -46.3875005,
#           "sv": null,
#           "is": null
#         },
#         {
#           "p": 32155,
#           "a": true,
#           "ta": "2025-01-22T23:04:54Z",
#           "py": -23.498499000000002,
#           "px": -46.46443599999999,
#           "sv": null,
#           "is": null
#         },
#         {
#           "p": 32515,
#           "a": true,
#           "ta": "2025-01-22T23:04:25Z",
#           "py": -23.5335115,
#           "px": -46.47354249999999,
#           "sv": null,
#           "is": null
#         },
#         {
#           "p": 32096,
#           "a": true,
#           "ta": "2025-01-22T23:04:45Z",
#           "py": -23.540174,
#           "px": -46.483585500000004,
#           "sv": null,
#           "is": null
#         }
#       ]
#     },
#     {
#       "c": "574J-10",
#       "cl": 34453,
#       "sl": 2,
#       "lt0": "TERM. VL. CARR\u00c3O",
#       "lt1": "METR\u00d4 CONCEI\u00c7\u00c3O",
#       "qv": 10,
#       "vs": [
#         {
#           "p": 52909,
#           "a": true,
#           "ta": "2025-01-22T23:04:53Z",
#           "py": -23.636083499999998,
#           "px": -46.641462,
#           "sv": null,
#           "is": null
#         },
#         {
#           "p": 52137,
#           "a": true,
#           "ta": "2025-01-22T23:05:06Z",
#           "py": -23.6225685,
#           "px": -46.629061500000006,
#           "sv": null,
#           "is": null
#         },
#         {
#           "p": 52914,
#           "a": true,
#           "ta": "2025-01-22T23:04:51Z",
#           "py": -23.5716525,
#           "px": -46.536777,
#           "sv": null,
#           "is": null
#         },
#         {
#           "p": 52915,
#           "a": true,
#           "ta": "2025-01-22T23:04:47Z",
#           "py": -23.558235500000002,
#           "px": -46.522756,
#           "sv": null,
#           "is": null
#         },
#         {
#           "p": 52104,
#           "a": true,
#           "ta": "2025-01-22T23:04:58Z",
#           "py": -23.5762115,
#           "px": -46.572743,
#           "sv": null,
#           "is": null
#         },
#         {
#           "p": 52901,
#           "a": true,
#           "ta": "2025-01-22T23:04:39Z",
#           "py": -23.6002985,
#           "px": -46.60046475,
#           "sv": null,
#           "is": null
#         },
#         {
#           "p": 52944,
#           "a": true,
#           "ta": "2025-01-22T23:04:45Z",
#           "py": -23.619402,
#           "px": -46.603479625000006,
#           "sv": null,
#           "is": null
#         },
#         {
#           "p": 52906,
#           "a": true,
#           "ta": "2025-01-22T23:04:37Z",
#           "py": -23.6251825,
#           "px": -46.62503275,
#           "sv": null,
#           "is": null
#         },
#         {
#           "p": 52937,
#           "a": true,
#           "ta": "2025-01-22T23:04:20Z",
#           "py": -23.571804375,
#           "px": -46.561348875,
#           "sv": null,
#           "is": null
#         },
#         {
#           "p": 52928,
#           "a": true,
#           "ta": "2025-01-22T23:04:53Z",
#           "py": -23.622748,
#           "px": -46.629258500000006,
#           "sv": null,
#           "is": null
#         }
#       ]
#     },
#     {
#       "c": "5029-10",
#       "cl": 34440,
#       "sl": 2,
#       "lt0": "TERM. SACOM\u00c3",
#       "lt1": "JD. PATENTE",
#       "qv": 6,
#       "vs": [
#         {
#           "p": 51455,
#           "a": true,
#           "ta": "2025-01-22T23:05:04Z",
#           "py": -23.621566,
#           "px": -46.59446975,
#           "sv": null,
#           "is": null
#         },
#         {
#           "p": 51414,
#           "a": true,
#           "ta": "2025-01-22T23:04:54Z",
#           "py": -23.628492,
#           "px": -46.5859155,
#           "sv": null,
#           "is": null
#         },
#         {
#           "p": 51103,
#           "a": true,
#           "ta": "2025-01-22T23:04:41Z",
#           "py": -23.6284755,
#           "px": -46.5863025,
#           "sv": null,
#           "is": null
#         },
#         {
#           "p": 51453,
#           "a": true,
#           "ta": "2025-01-22T23:04:34Z",
#           "py": -23.628492,
#           "px": -46.5859155,
#           "sv": null,
#           "is": null
#         },
#         {
#           "p": 51420,
#           "a": true,
#           "ta": "2025-01-22T23:04:51Z",
#           "py": -23.621262,
#           "px": -46.585988,
#           "sv": null,
#           "is": null
#         },
#         {
#           "p": 51064,
#           "a": true,
#           "ta": "2025-01-22T23:04:41Z",
#           "py": -23.6034085,
#           "px": -46.6026285,
#           "sv": null,
#           "is": null
#         }
#       ]
#     },
#     {
#       "c": "1773-10",
#       "cl": 637,
#       "sl": 1,
#       "lt0": "MANDAQUI",
#       "lt1": "CEM. PQ. DOS PINHEIROS",
#       "qv": 5,
#       "vs": [
#         {
#           "p": 22058,
#           "a": true,
#           "ta": "2025-01-22T23:04:54Z",
#           "py": -23.438668,
#           "px": -46.5865085,
#           "sv": null,
#           "is": null
#         },
#         {
#           "p": 22539,
#           "a": true,
#           "ta": "2025-01-22T23:05:05Z",
#           "py": -23.4825085,
#           "px": -46.630541,
#           "sv": null,
#           "is": null
#         },
#         {
#           "p": 22538,
#           "a": true,
#           "ta": "2025-01-22T23:04:26Z",
#           "py": -23.4826065,
#           "px": -46.6307425,
#           "sv": null,
#           "is": null
#         },
#         {
#           "p": 22533,
#           "a": true,
#           "ta": "2025-01-22T23:04:55Z",
#           "py": -23.479685,
#           "px": -46.6114135,
#           "sv": null,
#           "is": null
#         },
#         {
#           "p": 22845,
#           "a": true,
#           "ta": "2025-01-22T23:04:40Z",
#           "py": -23.468738000000002,
#           "px": -46.608924,
#           "sv": null,
#           "is": null
#         }
#       ]
#     },
#     {
#       "c": "5018-10",
#       "cl": 1492,
#       "sl": 1,
#       "lt0": "JABAQUARA",
#       "lt1": "SHOP. INTERLAGOS",
#       "qv": 2,
#       "vs": [
#         {
#           "p": 68064,
#           "a": true,
#           "ta": "2025-01-22T23:04:36Z",
#           "py": -23.6908235,
#           "px": -46.6702705,
#           "sv": null,
#           "is": null
#         },
#         {
#           "p": 68140,
#           "a": true,
#           "ta": "2025-01-22T23:04:30Z",
#           "py": -23.675069,
#           "px": -46.673212,
#           "sv": null,
#           "is": null
#         }
#       ]
#     },
#     {
#       "c": "9014-10",
#       "cl": 1425,
#       "sl": 1,
#       "lt0": "TERM. LAPA",
#       "lt1": "MORRO GRANDE",
#       "qv": 5,
#       "vs": [
#         {
#           "p": 13674,
#           "a": true,
#           "ta": "2025-01-22T23:04:35Z",
#           "py": -23.4748515,
#           "px": -46.708434,
#           "sv": null,
#           "is": null
#         },
#         {
#           "p": 13525,
#           "a": true,
#           "ta": "2025-01-22T23:04:27Z",
#           "py": -23.513580750000003,
#           "px": -46.69078775,
#           "sv": null,
#           "is": null
#         },
#         {
#           "p": 13671,
#           "a": true,
#           "ta": "2025-01-22T23:04:46Z",
#           "py": -23.47469,
#           "px": -46.7083305,
#           "sv": null,
#           "is": null
#         },
#         {
#           "p": 13545,
#           "a": true,
#           "ta": "2025-01-22T23:05:00Z",
#           "py": -23.4966025,
#           "px": -46.69781125,
#           "sv": null,
#           "is": null
#         },
#         {
#           "p": 13640,
#           "a": true,
#           "ta": "2025-01-22T23:04:41Z",
#           "py": -23.474511999999997,
#           "px": -46.7082465,
#           "sv": null,
#           "is": null
#         }
#       ]
#     },
#     {
#       "c": "172N-10",
#       "cl": 664,
#       "sl": 1,
#       "lt0": "METR\u00d4 BEL\u00c9M",
#       "lt1": "SHOP. CENTER NORTE",
#       "qv": 4,
#       "vs": [
#         {
#           "p": 21375,
#           "a": true,
#           "ta": "2025-01-22T23:04:38Z",
#           "py": -23.5422945,
#           "px": -46.58958,
#           "sv": null,
#           "is": null
#         },
#         {
#           "p": 21730,
#           "a": true,
#           "ta": "2025-01-22T23:04:53Z",
#           "py": -23.5078945,
#           "px": -46.601945,
#           "sv": null,
#           "is": null
#         },
#         {
#           "p": 21732,
#           "a": true,
#           "ta": "2025-01-22T23:04:29Z",
#           "py": -23.505131125,
#           "px": -46.624702875,
#           "sv": null,
#           "is": null
#         },
#         {
#           "p": 21744,
#           "a": true,
#           "ta": "2025-01-22T23:04:39Z",
#           "py": -23.514157124999997,
#           "px": -46.586495375000005,
#           "sv": null,
#           "is": null
#         }
#       ]
#     },
#     {
#       "c": "7550-10",
#       "cl": 34861,
#       "sl": 2,
#       "lt0": "METR\u00d4 STA. CEC\u00cdLIA",
#       "lt1": "TERM. STO. AMARO",
#       "qv": 6,
#       "vs": [
#         {
#           "p": 76315,
#           "a": true,
#           "ta": "2025-01-22T23:04:50Z",
#           "py": -23.539453,
#           "px": -46.6480085,
#           "sv": null,
#           "is": null
#         },
#         {
#           "p": 76301,
#           "a": true,
#           "ta": "2025-01-22T23:05:04Z",
#           "py": -23.6301995,
#           "px": -46.690188,
#           "sv": null,
#           "is": null
#         },
#         {
#           "p": 76327,
#           "a": true,
#           "ta": "2025-01-22T23:05:07Z",
#           "py": -23.600961499999997,
#           "px": -46.67407025,
#           "sv": null,
#           "is": null
#         },
#         {
#           "p": 76313,
#           "a": true,
#           "ta": "2025-01-22T23:04:30Z",
#           "py": -23.565011375,
#           "px": -46.647259000000005,
#           "sv": null,
#           "is": null
#         },
#         {
#           "p": 76048,
#           "a": true,
#           "ta": "2025-01-22T23:04:53Z",
#           "py": -23.544515125,
#           "px": -46.644026874999994,
#           "sv": null,
#           "is": null
#         },
#         {
#           "p": 76312,
#           "a": true,
#           "ta": "2025-01-22T23:04:43Z",
#           "py": -23.654181,
#           "px": -46.711629,
#           "sv": null,
#           "is": null
#         }
#       ]
#     },
#     {
#       "c": "707A-10",
#       "cl": 1990,
#       "sl": 1,
#       "lt0": "METR\u00d4 P\u00c7A. DA \u00c1RVORE",
#       "lt1": "JD. \u00c2NGELA",
#       "qv": 8,
#       "vs": [
#         {
#           "p": 73975,
#           "a": true,
#           "ta": "2025-01-22T23:05:04Z",
#           "py": -23.683419999999998,
#           "px": -46.76925,
#           "sv": null,
#           "is": null
#         },
#         {
#           "p": 73008,
#           "a": true,
#           "ta": "2025-01-22T23:04:56Z",
#           "py": -23.667369,
#           "px": -46.728165,
#           "sv": null,
#           "is": null
#         },
#         {
#           "p": 73969,
#           "a": true,
#           "ta": "2025-01-22T23:04:32Z",
#           "py": -23.6671635,
#           "px": -46.725606,
#           "sv": null,
#           "is": null
#         },
#         {
#           "p": 73936,
#           "a": true,
#           "ta": "2025-01-22T23:04:49Z",
#           "py": -23.662343874999998,
#           "px": -46.706628,
#           "sv": null,
#           "is": null
#         },
#         {
#           "p": 73939,
#           "a": true,
#           "ta": "2025-01-22T23:05:04Z",
#           "py": -23.655837,
#           "px": -46.706608,
#           "sv": null,
#           "is": null
#         },
#         {
#           "p": 73973,
#           "a": true,
#           "ta": "2025-01-22T23:04:48Z",
#           "py": -23.605968124999997,
#           "px": -46.65834875,
#           "sv": null,
#           "is": null
#         },
#         {
#           "p": 73012,
#           "a": true,
#           "ta": "2025-01-22T23:04:56Z",
#           "py": -23.665831500000003,
#           "px": -46.7126115,
#           "sv": null,
#           "is": null
#         },
#         {
#           "p": 73647,
#           "a": true,
#           "ta": "2025-01-22T23:05:01Z",
#           "py": -23.619649,
#           "px": -46.67723875,
#           "sv": null,
#           "is": null
#         }
#       ]
#     },
#     {
#       "c": "574W-10",
#       "cl": 34397,
#       "sl": 2,
#       "lt0": "METR\u00d4 BEL\u00c9M",
#       "lt1": "JD. WALKIRIA",
#       "qv": 7,
#       "vs": [
#         {
#           "p": 55472,
#           "a": true,
#           "ta": "2025-01-22T23:04:36Z",
#           "py": -23.61519175,
#           "px": -46.48790975,
#           "sv": null,
#           "is": null
#         },
#         {
#           "p": 55330,
#           "a": true,
#           "ta": "2025-01-22T23:04:55Z",
#           "py": -23.562294,
#           "px": -46.556946999999994,
#           "sv": null,
#           "is": null
#         },
#         {
#           "p": 55053,
#           "a": true,
#           "ta": "2025-01-22T23:04:36Z",
#           "py": -23.585531000000003,
#           "px": -46.519232,
#           "sv": null,
#           "is": null
#         },
#         {
#           "p": 55412,
#           "a": true,
#           "ta": "2025-01-22T23:05:08Z",
#           "py": -23.615775499999998,
#           "px": -46.488022,
#           "sv": null,
#           "is": null
#         },
#         {
#           "p": 55244,
#           "a": true,
#           "ta": "2025-01-22T23:04:30Z",
#           "py": -23.6161065,
#           "px": -46.4880085,
#           "sv": null,
#           "is": null
#         },
#         {
#           "p": 55076,
#           "a": true,
#           "ta": "2025-01-22T23:04:34Z",
#           "py": -23.6129695,
#           "px": -46.4915855,
#           "sv": null,
#           "is": null
#         },
#         {
#           "p": 55155,
#           "a": true,
#           "ta": "2025-01-22T23:05:00Z",
#           "py": -23.615775499999998,
#           "px": -46.488022,
#           "sv": null,
#           "is": null
#         }
#       ]
#     },
#     {
#       "c": "5290-10",
#       "cl": 597,
#       "sl": 1,
#       "lt0": "TERM. PQ. D. PEDRO II",
#       "lt1": "DIV. DIADEMA",
#       "qv": 7,
#       "vs": [
#         {
#           "p": 63372,
#           "a": true,
#           "ta": "2025-01-22T23:04:56Z",
#           "py": -23.6816055,
#           "px": -46.6367515,
#           "sv": null,
#           "is": null
#         },
#         {
#           "p": 63357,
#           "a": true,
#           "ta": "2025-01-22T23:04:39Z",
#           "py": -23.611379499999998,
#           "px": -46.6378325,
#           "sv": null,
#           "is": null
#         },
#         {
#           "p": 63288,
#           "a": true,
#           "ta": "2025-01-22T23:04:36Z",
#           "py": -23.6776175,
#           "px": -46.629261,
#           "sv": null,
#           "is": null
#         },
#         {
#           "p": 63380,
#           "a": true,
#           "ta": "2025-01-22T23:04:45Z",
#           "py": -23.628699124999997,
#           "px": -46.644809625,
#           "sv": null,
#           "is": null
#         },
#         {
#           "p": 63258,
#           "a": true,
#           "ta": "2025-01-22T23:04:38Z",
#           "py": -23.555402,
#           "px": -46.635875999999996,
#           "sv": null,
#           "is": null
#         },
#         {
#           "p": 63166,
#           "a": true,
#           "ta": "2025-01-22T23:04:43Z",
#           "py": -23.639956499999997,
#           "px": -46.641329999999996,
#           "sv": null,
#           "is": null
#         },
#         {
#           "p": 63356,
#           "a": true,
#           "ta": "2025-01-22T23:04:46Z",
#           "py": -23.552137000000002,
#           "px": -46.634062,
#           "sv": null,
#           "is": null
#         }
#       ]
#     },
#     {
#       "c": "2734-10",
#       "cl": 34528,
#       "sl": 2,
#       "lt0": "METR\u00d4 ITAQUERA",
#       "lt1": "JD. CAMPOS",
#       "qv": 5,
#       "vs": [
#         {
#           "p": 35826,
#           "a": true,
#           "ta": "2025-01-22T23:04:30Z",
#           "py": -23.50992075,
#           "px": -46.41216775,
#           "sv": null,
#           "is": null
#         },
#         {
#           "p": 35757,
#           "a": true,
#           "ta": "2025-01-22T23:04:37Z",
#           "py": -23.519289,
#           "px": -46.440655500000005,
#           "sv": null,
#           "is": null
#         },
#         {
#           "p": 35782,
#           "a": true,
#           "ta": "2025-01-22T23:04:22Z",
#           "py": -23.50829525,
#           "px": -46.42330025,
#           "sv": null,
#           "is": null
#         },
#         {
#           "p": 35713,
#           "a": true,
#           "ta": "2025-01-22T23:04:58Z",
#           "py": -23.5110655,
#           "px": -46.409795,
#           "sv": null,
#           "is": null
#         },
#         {
#           "p": 35992,
#           "a": true,
#           "ta": "2025-01-22T23:04:41Z",
#           "py": -23.5100245,
#           "px": -46.422072,
#           "sv": null,
#           "is": null
#         }
#       ]
#     },
#     {
#       "c": "2717-10",
#       "cl": 930,
#       "sl": 1,
#       "lt0": "CANGA\u00cdBA",
#       "lt1": "METR\u00d4 GUILHERMINA/ESPERAN\u00c7A",
# ...
#           "is": null
#         }
#       ]
#     },
#     {
#       "c": "4706-10",
#       "cl": 299,
#       "sl": 1,
#       "lt0": "METR\u00d4 VL. MARIANA",
#       "lt1": "JD. MARIA ESTELA II",
#       "qv": 1,
#       "vs": [
#         {
#           "p": 51452,
#           "a": true,
#           "ta": "2025-01-22T23:05:03Z",
#           "py": -23.5928405,
#           "px": -46.621369,
#           "sv": null,
#           "is": null
#         }
#       ]
#     },
#     {
#       "c": "139A-10",
#       "cl": 2451,
#       "sl": 1,
#       "lt0": "LAPA",
#       "lt1": "VL. I\u00d3RIO",
#       "qv": 1,
#       "vs": [
#         {
#           "p": 16403,
#           "a": true,
#           "ta": "2025-01-22T23:04:47Z",
#           "py": -23.51404025,
#           "px": -46.703658000000004,
#           "sv": null,
#           "is": null
#         }
#       ]
#     },
#     {
#       "c": "2005-10",
#       "cl": 893,
#       "sl": 1,
#       "lt0": "S\u00c3O MIGUEL",
#       "lt1": "JD. ROMANO",
#       "qv": 1,
#       "vs": [
#         {
#           "p": 36017,
#           "a": true,
#           "ta": "2025-01-22T23:04:43Z",
#           "py": -23.481623749999997,
#           "px": -46.37878275,
#           "sv": null,
#           "is": null
#         }
#       ]
#     },
#     {
#       "c": "8047-41",
#       "cl": 410,
#       "sl": 1,
#       "lt0": "METR\u00d4 VL. MADALENA",
#       "lt1": "JARAGU\u00c1",
#       "qv": 1,
#       "vs": [
#         {
#           "p": 10223,
#           "a": true,
#           "ta": "2025-01-22T23:04:49Z",
#           "py": -23.5237295,
#           "px": -46.74233925,
#           "sv": null,
#           "is": null
#         }
#       ]
#     },
#     {
#       "c": "178A-10",
#       "cl": 558,
#       "sl": 1,
#       "lt0": "LAPA",
#       "lt1": "METR\u00d4 SANTANA",
#       "qv": 2,
#       "vs": [
#         {
#           "p": 21871,
#           "a": true,
#           "ta": "2025-01-22T23:05:07Z",
#           "py": -23.5263085,
#           "px": -46.6738405,
#           "sv": null,
#           "is": null
#         },
#         {
#           "p": 21354,
#           "a": true,
#           "ta": "2025-01-22T23:04:44Z",
#           "py": -23.531662999999998,
#           "px": -46.635698,
#           "sv": null,
#           "is": null
#         }
#       ]
#     },
#     {
#       "c": "809U-10",
#       "cl": 2254,
#       "sl": 1,
#       "lt0": "METR\u00d4 BARRA FUNDA",
#       "lt1": "CID. UNIVERSIT\u00c1RIA",
#       "qv": 1,
#       "vs": [
#         {
#           "p": 82465,
#           "a": true,
#           "ta": "2025-01-22T23:04:36Z",
#           "py": -23.54570175,
#           "px": -46.700842249999994,
#           "sv": null,
#           "is": null
#         }
#       ]
#     },
#     {
#       "c": "7411-10",
#       "cl": 1376,
#       "sl": 1,
#       "lt0": "P\u00c7A. DA S\u00c9",
#       "lt1": "CID. UNIVERSIT\u00c1RIA",
#       "qv": 1,
#       "vs": [
#         {
#           "p": 82575,
#           "a": true,
#           "ta": "2025-01-22T23:04:53Z",
#           "py": -23.570693125,
#           "px": -46.7104935,
#           "sv": null,
#           "is": null
#         }
#       ]
#     },
#     {
#       "c": "5107-10",
#       "cl": 34427,
#       "sl": 2,
#       "lt0": "P\u00c7A. DO CORREIO",
#       "lt1": "TERM. SACOM\u00c3",
#       "qv": 1,
#       "vs": [
#         {
#           "p": 52142,
#           "a": true,
#           "ta": "2025-01-22T23:04:22Z",
#           "py": -23.579744875000003,
#           "px": -46.604672375,
#           "sv": null,
#           "is": null
#         }
#       ]
#     },
#     {
#       "c": "4735-10",
#       "cl": 33878,
#       "sl": 2,
#       "lt0": "JD. VERA CRUZ",
#       "lt1": "S\u00c3O MATEUS  ",
#       "qv": 2,
#       "vs": [
#         {
#           "p": 55343,
#           "a": true,
#           "ta": "2025-01-22T23:04:37Z",
#           "py": -23.610017,
#           "px": -46.480343500000004,
#           "sv": null,
#           "is": null
#         },
#         {
#           "p": 55146,
#           "a": true,
#           "ta": "2025-01-22T23:05:02Z",
#           "py": -23.6184525,
#           "px": -46.4716965,
#           "sv": null,
#           "is": null
#         }
#       ]
#     },
#     {
#       "c": "513L-10",
#       "cl": 34423,
#       "sl": 2,
#       "lt0": "PQ. BEL\u00c9M",
#       "lt1": "TERM. SACOM\u00c3",
#       "qv": 1,
#       "vs": [
#         {
#           "p": 51069,
#           "a": true,
#           "ta": "2025-01-22T23:04:49Z",
#           "py": -23.600665499999998,
#           "px": -46.60042824999999,
#           "sv": null,
#           "is": null
#         }
#       ]
#     },
#     {
#       "c": "273F-10",
#       "cl": 32927,
#       "sl": 2,
#       "lt0": "METR\u00d4 ITAQUERA",
#       "lt1": "VL. MARA",
#       "qv": 2,
#       "vs": [
#         {
#           "p": 32021,
#           "a": true,
#           "ta": "2025-01-22T23:04:49Z",
#           "py": -23.5042555,
#           "px": -46.442893,
#           "sv": null,
#           "is": null
#         },
#         {
#           "p": 32015,
#           "a": true,
#           "ta": "2025-01-22T23:04:40Z",
#           "py": -23.489485625,
#           "px": -46.421352,
#           "sv": null,
#           "is": null
#         }
#       ]
#     },
#     {
#       "c": "4286-10",
#       "cl": 326,
#       "sl": 1,
#       "lt0": "TERM. VL PRUDENTE",
#       "lt1": "VL. INDUSTRIAL",
#       "qv": 1,
#       "vs": [
#         {
#           "p": 51005,
#           "a": true,
#           "ta": "2025-01-22T23:04:51Z",
#           "py": -23.601392500000003,
#           "px": -46.5396365,
#           "sv": null,
#           "is": null
#         }
#       ]
#     },
#     {
#       "c": "2024-10",
#       "cl": 35029,
#       "sl": 2,
#       "lt0": "CACHOEIRA",
#       "lt1": "DIB",
#       "qv": 1,
#       "vs": [
#         {
#           "p": 22633,
#           "a": true,
#           "ta": "2025-01-22T23:00:49Z",
#           "py": -23.3735605,
#           "px": -46.5753715,
#           "sv": null,
#           "is": null
#         }
#       ]
#     },
#     {
#       "c": "5143-10",
#       "cl": 1628,
#       "sl": 1,
#       "lt0": "TERM. PQ. D. PEDRO II",
#       "lt1": "TERM. SAPOPEMBA",
#       "qv": 1,
#       "vs": [
#         {
#           "p": 52135,
#           "a": true,
#           "ta": "2025-01-22T23:04:49Z",
#           "py": -23.614242,
#           "px": -46.501176,
#           "sv": null,
#           "is": null
#         }
#       ]
#     },
#     {
#       "c": "573T-31",
#       "cl": 2248,
#       "sl": 1,
#       "lt0": "METR\u00d4 CARR\u00c3O",
#       "lt1": "TERM. SAPOPEMBA",
#       "qv": 1,
#       "vs": [
#         {
#           "p": 55411,
#           "a": true,
#           "ta": "2025-01-22T23:04:25Z",
#           "py": -23.596009375,
#           "px": -46.488282125,
#           "sv": null,
#           "is": null
#         }
#       ]
#     },
#     {
#       "c": "7062-10",
#       "cl": 34666,
#       "sl": 2,
#       "lt0": "TERM. CAMPO LIMPO",
#       "lt1": "INOCOOP CAMPO LIMPO",
#       "qv": 1,
#       "vs": [
#         {
#           "p": 78236,
#           "a": true,
#           "ta": "2025-01-22T23:04:29Z",
#           "py": -23.646199000000003,
#           "px": -46.772373,
#           "sv": null,
#           "is": null
#         }
#       ]
#     },
#     {
#       "c": "809N-10",
#       "cl": 2244,
#       "sl": 1,
#       "lt0": "LAPA",
#       "lt1": "VL. DALVA",
#       "qv": 2,
#       "vs": [
#         {
#           "p": 80997,
#           "a": true,
#           "ta": "2025-01-22T23:04:54Z",
#           "py": -23.5673305,
#           "px": -46.765161500000005,
#           "sv": null,
#           "is": null
#         },
#         {
#           "p": 80361,
#           "a": true,
#           "ta": "2025-01-22T23:04:40Z",
#           "py": -23.52371125,
#           "px": -46.69773975,
#           "sv": null,
#           "is": null
#         }
#       ]
#     },
#     {
#       "c": "606Z-10",
#       "cl": 2611,
#       "sl": 1,
#       "lt0": "BALN. MAR PAULISTA",
#       "lt1": "CIRCULAR",
#       "qv": 1,
#       "vs": [
#         {
#           "p": 68405,
#           "a": true,
#           "ta": "2025-01-22T23:05:06Z",
#           "py": -23.697134,
#           "px": -46.665673,
#           "sv": null,
#           "is": null
#         }
#       ]
#     },
#     {
#       "c": "6823-10",
#       "cl": 34,
#       "sl": 1,
#       "lt0": "TERM. CAPELINHA",
#       "lt1": "JD. GUARUJ\u00c1",
#       "qv": 1,
#       "vs": [
#         {
#           "p": 72945,
#           "a": true,
#           "ta": "2025-01-22T23:04:25Z",
#           "py": -23.659846,
#           "px": -46.769888,
#           "sv": null,
#           "is": null
#         }
#       ]
#     },
#     {
#       "c": "6012-31",
#       "cl": 34544,
#       "sl": 2,
#       "lt0": "JD. \u00c2NGELA",
#       "lt1": "PQ. INDEPEND\u00caNCIA",
#       "qv": 1,
#       "vs": [
#         {
#           "p": 78910,
#           "a": true,
#           "ta": "2025-01-22T23:04:59Z",
#           "py": -23.69617775,
#           "px": -46.7828645,
#           "sv": null,
#           "is": null
#         }
#       ]
#     },
#     {
#       "c": "6012-31",
#       "cl": 1776,
#       "sl": 1,
#       "lt0": "JD. \u00c2NGELA",
#       "lt1": "PQ. INDEPEND\u00caNCIA",
#       "qv": 1,
#       "vs": [
#         {
#           "p": 78925,
#           "a": true,
#           "ta": "2025-01-22T23:04:54Z",
#           "py": -23.689284500000003,
#           "px": -46.77324575,
#           "sv": null,
#           "is": null
#         }
#       ]
#     },
#     {
#       "c": "8086-10",
#       "cl": 2621,
#       "sl": 1,
#       "lt0": "PINHEIROS",
#       "lt1": "JAGUAR\u00c9",
#       "qv": 1,
#       "vs": [
#         {
#           "p": 82005,
#           "a": true,
#           "ta": "2025-01-22T23:04:49Z",
#           "py": -23.56104775,
#           "px": -46.726283249999994,
#           "sv": null,
#           "is": null
#         }
#       ]
#     },
#     {
#       "c": "5106-31",
#       "cl": 1305,
#       "sl": 1,
#       "lt0": "METR\u00d4 ANA ROSA",
#       "lt1": "JD. SELMA",
#       "qv": 1,
#       "vs": [
#         {
#           "p": 63280,
#           "a": true,
#           "ta": "2025-01-22T23:04:51Z",
#           "py": -23.657823999999998,
#           "px": -46.635857,
#           "sv": null,
#           "is": null
#         }
#       ]
#     },
#     {
#       "c": "5031-21",
#       "cl": 34515,
#       "sl": 2,
#       "lt0": "TERM. SACOM\u00c3",
#       "lt1": "VL. CDE. DO PINHAL",
#       "qv": 1,
#       "vs": [
#         {
#           "p": 55476,
#           "a": true,
#           "ta": "2025-01-22T23:04:45Z",
#           "py": -23.60798475,
#           "px": -46.597176499999996,
#           "sv": null,
#           "is": null
#         }
#       ]
#     },
#     {
#       "c": "1720-21",
#       "cl": 34705,
#       "sl": 2,
#       "lt0": "METR\u00d4 TUCURUVI",
#       "lt1": "VILA SABRINA",
#       "qv": 1,
#       "vs": [
#         {
#           "p": 26101,
#           "a": true,
#           "ta": "2025-01-22T23:04:53Z",
#           "py": -23.479202,
#           "px": -46.576089499999995,
#           "sv": null,
#           "is": null
#         }
#       ]
#     },
#     {
#       "c": "2709-10",
#       "cl": 33690,
#       "sl": 2,
#       "lt0": "VL. UNI\u00c3O",
#       "lt1": "METR\u00d4 PATRIARCA",
#       "qv": 1,
#       "vs": [
#         {
#           "p": 45741,
#           "a": true,
#           "ta": "2025-01-22T23:04:25Z",
#           "py": -23.529722,
#           "px": -46.500626,
#           "sv": null,
#           "is": null
#         }
#       ]
#     },
#     {
#       "c": "8010-21",
#       "cl": 1737,
#       "sl": 1,
#       "lt0": "S\u00cdTIO BOTUQUARA",
#       "lt1": "CPTM PERUS",
#       "qv": 1,
#       "vs": [
#         {
#           "p": 16767,
#           "a": true,
#           "ta": "2025-01-22T23:04:45Z",
#           "py": -23.41113775,
#           "px": -46.734978749999996,
#           "sv": null,
#           "is": null
#         }
#       ]
#     },
#     {
#       "c": "8006-10",
#       "cl": 1256,
#       "sl": 1,
#       "lt0": "TERM. PIRITUBA",
#       "lt1": "JD. DON\u00c1RIA",
#       "qv": 1,
#       "vs": [
#         {
#           "p": 10485,
#           "a": true,
#           "ta": "2025-01-22T23:05:05Z",
#           "py": -23.4647935,
#           "px": -46.721514,
#           "sv": null,
#           "is": null
#         }
#       ]
#     },
#     {
#       "c": "2710-31",
#       "cl": 34422,
#       "sl": 2,
#       "lt0": "TERM. A. E. CARVALHO",
#       "lt1": "METR\u00d4 PATRIARCA",
#       "qv": 1,
#       "vs": [
#         {
#           "p": 45216,
#           "a": true,
#           "ta": "2025-01-22T23:04:51Z",
#           "py": -23.529739,
#           "px": -46.501110999999995,
#           "sv": null,
#           "is": null
#         }
#       ]
#     },
#     {
#       "c": "407M-10",
#       "cl": 33086,
#       "sl": 2,
#       "lt0": "METR\u00d4 VL. MARIANA",
#       "lt1": "VL. MONUMENTO",
#       "qv": 1,
#       "vs": [
#         {
#           "p": 51016,
#           "a": true,
#           "ta": "2025-01-22T23:04:58Z",
#           "py": -23.5757655,
#           "px": -46.6136105,
#           "sv": null,
#           "is": null
#         }
#       ]
#     },
#     {
#       "c": "8043-10",
#       "cl": 407,
#       "sl": 1,
#       "lt0": "LAPA",
#       "lt1": "HAB. TUR\u00cdSTICA",
#       "qv": 1,
#       "vs": [
#         {
#           "p": 10410,
#           "a": true,
#           "ta": "2025-01-22T23:05:01Z",
#           "py": -23.4792985,
#           "px": -46.7475335,
#           "sv": null,
#           "is": null
#         }
#       ]
#     },
#     {
#       "c": "2030-10",
#       "cl": 35032,
#       "sl": 2,
#       "lt0": "METR\u00d4 SANTANA",
#       "lt1": "LAUZANE PAULISTA",
#       "qv": 1,
#       "vs": [
#         {
#           "p": 22303,
#           "a": true,
#           "ta": "2025-01-22T23:04:48Z",
#           "py": -23.47218025,
#           "px": -46.641837624999994,
#           "sv": null,
#           "is": null
#         }
#       ]
#     },
#     {
#       "c": "6020-10",
#       "cl": 2455,
#       "sl": 1,
#       "lt0": "PARELHEIROS",
#       "lt1": "CH\u00c1C. BOSQUE DO SOL",
#       "qv": 1,
#       "vs": [
#         {
#           "p": 66877,
#           "a": true,
#           "ta": "2025-01-22T23:05:05Z",
#           "py": -23.826263,
#           "px": -46.7441395,
#           "sv": null,
#           "is": null
#         }
#       ]
#     },
#     {
#       "c": "8007-10",
#       "cl": 1257,
#       "sl": 1,
#       "lt0": "TERM. PIRITUBA",
#       "lt1": "HAB. TUR\u00cdSTICA",
#       "qv": 1,
#       "vs": [
#         {
#           "p": 10602,
#           "a": true,
#           "ta": "2025-01-22T23:05:01Z",
#           "py": -23.469352999999998,
#           "px": -46.752537000000004,
#           "sv": null,
#           "is": null
#         }
#       ]
#     },
#     {
#       "c": "3725-41",
#       "cl": 34299,
#       "sl": 2,
#       "lt0": "VL. ARICANDUVA",
#       "lt1": "METR\u00d4 VL. MATILDE",
#       "qv": 1,
#       "vs": [
#         {
#           "p": 45316,
#           "a": true,
#           "ta": "2025-01-22T23:04:39Z",
#           "py": -23.53899225,
#           "px": -46.528093,
#           "sv": null,
#           "is": null
#         }
#       ]
#     },
#     {
#       "c": "6813-10",
#       "cl": 33,
#       "sl": 1,
#       "lt0": "TERM. CAPELINHA",
#       "lt1": "JD. L\u00cdDIA",
#       "qv": 1,
#       "vs": [
#         {
#           "p": 72005,
#           "a": true,
#           "ta": "2025-01-22T23:05:04Z",
#           "py": -23.654061499999997,
#           "px": -46.763393,
#           "sv": null,
#           "is": null
#         }
#       ]
#     },
#     {
#       "c": "8252-10",
#       "cl": 34016,
#       "sl": 2,
#       "lt0": "LAPA",
#       "lt1": "METR\u00d4 BARRA FUNDA",
#       "qv": 1,
#       "vs": [
#         {
#           "p": 80138,
#           "a": true,
#           "ta": "2025-01-22T23:05:04Z",
#           "py": -23.533489,
#           "px": -46.702938,
#           "sv": null,
#           "is": null
#         }
#       ]
#     },
#     {
#       "c": "6003-10",
#       "cl": 34240,
#       "sl": 2,
#       "lt0": "TERM. VARGINHA",
#       "lt1": "TERM. GRAJA\u00da",
#       "qv": 1,
#       "vs": [
#         {
#           "p": 61569,
#           "a": true,
#           "ta": "2025-01-22T23:04:49Z",
#           "py": -23.75727,
#           "px": -46.7142405,
#           "sv": null,
#           "is": null
#         }
#       ]
#     },
#     {
#       "c": "701H-10",
#       "cl": 2558,
#       "sl": 1,
#       "lt0": "CIRCULAR",
#       "lt1": "HOSPITAL GUARAPIRANGA",
#       "qv": 1,
#       "vs": [
#         {
#           "p": 78840,
#           "a": true,
#           "ta": "2025-01-22T23:04:41Z",
#           "py": -23.700599,
#           "px": -46.75105275,
#           "sv": null,
#           "is": null
#         }
#       ]
#     },
#     {
#       "c": "3015-10",
#       "cl": 2454,
#       "sl": 1,
#       "lt0": "JD. MABEL",
#       "lt1": "JD. ROMANO",
#       "qv": 1,
#       "vs": [
#         {
#           "p": 32318,
#           "a": true,
#           "ta": "2025-01-22T23:04:35Z",
#           "py": -23.492131,
#           "px": -46.391062,
#           "sv": null,
#           "is": null
#         }
#       ]
#     }
#   ]
# }

# %%
import pandas as pd

BASE_PATH = 'trafi_gtfs'

df_agency = pd.read_csv(f'{BASE_PATH}/agency.txt', header=0)
df_agency.head()
# Out:
#    agency_id agency_name                                agency_url  \
# 0          1     SPTRANS  http://www.sptrans.com.br/?versao=200125
#
#      agency_timezone agency_lang
# 0  America/Sao_Paulo          pt

# %%
df_calendar = pd.read_csv(f'{BASE_PATH}/calendar.txt', header=0)
df_calendar.head()
# Out:
#   service_id  monday  tuesday  wednesday  thursday  friday  saturday  sunday  \
# 0        USD       1        1          1         1       1         1       1
# 1        U__       1        1          1         1       1         0       0
# 2        US_       1        1          1         1       1         1       0
# 3        _SD       0        0          0         0       0         1       1
# 4        __D       0        0          0         0       0         0       1
#
#    start_date  end_date
# 0    20231001  20250801
# 1    20231001  20250801
# 2    20231001  20250801
# 3    20231001  20250801
# 4    20231001  20250801

# %%
df_fare_attributes = pd.read_csv(f'{BASE_PATH}/fare_attributes.txt', header=0)
df_fare_attributes.head()
# Out:
#           fare_id  price currency_type  payment_method  transfers  \
# 0            CPTM    5.2           BRL               0        NaN
# 1           Metrô    5.2           BRL               0        NaN
# 2          Ônibus    5.0           BRL               0        NaN
# 3   Ônibus + CPTM    8.9           BRL               0        NaN
# 4  Ônibus + Metrô    8.9           BRL               0        NaN
#
#    transfer_duration
# 0              10800
# 1              10800
# 2              10800
# 3              10800
# 4              10800

# %%
df_fare_rules = pd.read_csv(f'{BASE_PATH}/fare_rules.txt', header=0)
df_fare_rules.head()
# Out:
#   fare_id  route_id  origin_id  destination_id  contains_id
# 0    CPTM  CPTM L07        NaN             NaN          NaN
# 1    CPTM  CPTM L08        NaN             NaN          NaN
# 2    CPTM  CPTM L09        NaN             NaN          NaN
# 3    CPTM  CPTM L10        NaN             NaN          NaN
# 4    CPTM  CPTM L11        NaN             NaN          NaN

# %%
df_frequencies = pd.read_csv(f'{BASE_PATH}/frequencies.txt', header=0)
df_frequencies.head()
# Out:
#      trip_id start_time  end_time  headway_secs
# 0  1012-10-0   00:00:00  00:59:00          1200
# 1  1012-10-0   01:00:00  01:59:00          3600
# 2  1012-10-0   05:00:00  05:59:00           600
# 3  1012-10-0   06:00:00  06:59:00           600
# 4  1012-10-0   07:00:00  07:59:00           600

# %%
df_routes = pd.read_csv(f'{BASE_PATH}/routes.txt', header=0)
df_routes.head()
# Out:
#   route_id  agency_id route_short_name  \
# 0  1012-10          1          1012-10
# 1  1012-21          1          1012-21
# 2  1014-10          1          1014-10
# 3  1015-10          1          1015-10
# 4  1016-10          1          1016-10
#
#                              route_long_name  route_type route_color  \
# 0        Term. Jd. Britania - Jd. Monte Belo           3      509E2F
# 1           Term. Jd. Britânia - Jd. Rosinha           3      509E2F
# 2                    Morro Doce - Cptm Perus           3      509E2F
# 3  Term. Jd. Britânia - Chác. Maria Trindade           3      509E2F
# 4         Cem. Do Horto - Shop. Center Norte           3      002F6C
#
#   route_text_color
# 0           FFFFFF
# 1           FFFFFF
# 2           FFFFFF
# 3           FFFFFF
# 4           FFFFFF

# %%
df_shapes = pd.read_csv(f'{BASE_PATH}/shapes.txt', header=0)
shape_pos = df_shapes[df_shapes['shape_id'] == 81072][['shape_pt_lat', 'shape_pt_lon']].values

# %%
from ipyleaflet import Map, Marker, FullScreenControl

avg_lat = sum(x[0] for x in shape_pos)/len(shape_pos)
avg_long = sum(x[1] for x in shape_pos)/len(shape_pos)

control = FullScreenControl()

# center = (-23.5558, -46.6396)
center = (avg_lat, avg_long)


m1 = Map(center=center, zoom=12)
m1.add_control(control)

for p in shape_pos:
    marker = Marker(location=tuple(p), draggable=False)
    m1.add(marker);

display(m1)
# Out:
# Map(center=[-23.436078552542355, -46.79888413220338], controls=(ZoomControl(options=['position', 'zoom_in_text…

# %%
df_stop_times = pd.read_csv(f'{BASE_PATH}/stop_times.txt', header=0)
df_stop_times.head()
# Out:
#      trip_id arrival_time departure_time   stop_id  stop_sequence
# 0  1012-10-0     18:00:00       18:00:00    301790              1
# 1  1012-10-0     18:01:35       18:01:35    301764              2
# 2  1012-10-0     18:03:10       18:03:10    301724              3
# 3  1012-10-0     18:04:45       18:04:45    301730              4
# 4  1012-10-0     18:06:20       18:06:20  30003042              5

# %%
df_stops = pd.read_csv(f'{BASE_PATH}/stops.txt', header=0)
print(df_stops.shape)
df_stops.head()
# Out:
# (21842, 5)
#    stop_id      stop_name stop_desc   stop_lat   stop_lon
# 0    18848       Clínicas       NaN -23.554022 -46.671108
# 1    18849  Vila Madalena       NaN -23.546498 -46.691141
# 2    18850     Consolação       NaN -23.558094 -46.660205
# 3    18851      Conceição       NaN -23.635039 -46.641239
# 4    18852      Jabaquara       NaN -23.646033 -46.641028

# %%
from ipyleaflet import Map, Marker, FullScreenControl
shape_pos = df_stops[['stop_lat', 'stop_lon']].values[:500] 

avg_lat = sum(x[0] for x in shape_pos)/len(shape_pos)
avg_long = sum(x[1] for x in shape_pos)/len(shape_pos)

control = FullScreenControl()

# center = (-23.5558, -46.6396)
center = (avg_lat, avg_long)


m1 = Map(center=center, zoom=12)
m1.add_control(control)

for p in shape_pos:
    marker = Marker(location=tuple(p), draggable=False)
    m1.add(marker);

display(m1)
# Out:
# Map(center=[-23.524372034, -46.63580856000003], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zo…

# %%
df_trips = pd.read_csv(f'{BASE_PATH}/trips.txt', header=0)
df_trips.head()
# Out:
#   route_id service_id    trip_id         trip_headsign  direction_id  shape_id
# 0  1012-10        USD  1012-10-0        Jd. Monte Belo             0     81072
# 1  1012-10        USD  1012-10-1    Term. Jd. Britania             1     81073
# 2  1012-21        U__  1012-21-0           Jd. Rosinha             0     81195
# 3  1014-10        U__  1014-10-0            Cptm Perus             0     82855
# 4  1015-10        USD  1015-10-0  Chác. Maria Trindade             0     81148
